# %%
import os
import sys
import glob
import pandas as pd
import math
import matplotlib.pyplot as plt
import celldancer as cd
import celldancer.cdplt as cdplt
from celldancer.cdplt import colormap
import scvelo as scv
import scanpy as sc
import celldancer.utilities as cdutil
import numpy as np
import seaborn as sns

# %%
adata = scv.datasets.dentategyrus()

# %%
scv.pl.proportions(adata, groupby = "clusters")

# %%
scv.pp.filter_and_normalize(adata, min_shared_counts=20, n_top_genes=2000)
scv.pp.moments(adata, n_pcs=30, n_neighbors=30)
# Out:
# Filtered out 10340 genes that are detected 20 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 2000 highly variable genes.
# Logarithmized X.
# computing neighbors
#     finished (0:00:02) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)

# %%
cdutil.adata_to_df_with_embed(adata,
                              us_para = ['Mu','Ms'],
                              cell_type_para = 'clusters',
                              embed_para = 'X_umap',
                              save_path = 'celldancer_predata.csv')
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 2000/2000 [00:14<00:00, 139.32it/s]
#         gene_name  unsplice    splice          cellID          clusters  \
# 0           Tcea1  0.059780  0.159322  AAACATACCCATGA  Granule immature
# 1           Tcea1  0.108118  0.617872  AAACATACCGTAGT  Radial Glia-like
# 2           Tcea1  0.210829  0.309992  AAACATACGAGAGC    Granule mature
# 3           Tcea1  0.052891  0.063903  AAACATACTGAGGG  Granule immature
# 4           Tcea1  0.067890  0.116002  AAACATTGGCATCA  Granule immature
# ...           ...       ...       ...             ...               ...
# 5859995     Kdm5d  0.000000  0.021940  TTTCTACTTCCCGT  Granule immature
# 5859996     Kdm5d  0.000000  0.000000  TTTGACTGCCTGTC        Neuroblast
# 5859997     Kdm5d  0.000000  0.013181  TTTGACTGTCTGGA    Granule mature
# 5859998     Kdm5d  0.000000  0.026178  TTTGCATGGGAGTG         Microglia
# 5859999     Kdm5d  0.008749  0.009732  TTTGCATGTTCTTG  Granule immature
#
#          embedding1  embedding2
# 0          2.731375   -8.038435
# 1         -1.500444   10.311057
# 2          1.577865  -11.268647
# 3         -1.202822   -1.029693
# 4          2.382317   -8.879890
# ...             ...         ...
# 5859995    1.149485   -2.563402
# 5859996   -3.285519    2.465202
# 5859997    0.024807   -8.033849
# 5859998    6.213368    5.104221
# 5859999    4.793736   -7.231717
#
# [5860000 rows x 7 columns]

# %%
cell_type_u_s = pd.read_csv('celldancer_predata.csv')

# %%
loss_df, cellDancer_df = cd.velocity(cell_type_u_s, permutation_ratio = 0.125, n_jobs = 16)
# Out:
# Using /media/data/bmi111/KuanChiun/temp/MultiVelo/thesis/results/dentategyrus/full/cellDancer_velocity_2024-05-22 23-10-00 as the output path.
# Arranging genes for parallel job.
# 2000  genes were arranged to  125  portions.
# Velocity Estimation:   0%|          | 0/125 [00:00<?, ?it/s]
# Velocity Estimation:   1%|          | 1/125 [00:05<12:03,  5.84s/it]
# Velocity Estimation:   2%|▏         | 2/125 [00:08<07:57,  3.88s/it]
# Velocity Estimation:   2%|▏         | 3/125 [00:11<06:45,  3.32s/it]
# Velocity Estimation:   3%|▎         | 4/125 [00:13<05:56,  2.95s/it]
# Velocity Estimation:   4%|▍         | 5/125 [00:16<05:43,  2.86s/it]
# Velocity Estimation:   5%|▍         | 6/125 [00:18<05:20,  2.69s/it]
# Velocity Estimation:   6%|▌         | 7/125 [00:21<05:18,  2.70s/it]
# Velocity Estimation:   6%|▋         | 8/125 [00:23<05:00,  2.57s/it]
# Velocity Estimation:   7%|▋         | 9/125 [00:26<05:09,  2.67s/it]
# Velocity Estimation:   8%|▊         | 10/125 [00:28<05:03,  2.64s/it]
# Velocity Estimation:   9%|▉         | 11/125 [00:31<04:52,  2.57s/it]
# Velocity Estimation:  10%|▉         | 12/125 [00:34<04:56,  2.62s/it]
# Velocity Estimation:  10%|█         | 13/125 [00:36<04:47,  2.56s/it]
# Velocity Estimation:  11%|█         | 14/125 [00:39<04:52,  2.64s/it]
# Velocity Estimation:  12%|█▏        | 15/125 [00:41<04:45,  2.60s/it]
# Velocity Estimation:  13%|█▎        | 16/125 [00:44<04:43,  2.60s/it]
# Velocity Estimation:  14%|█▎        | 17/125 [00:47<04:42,  2.62s/it]
# Velocity Estimation:  14%|█▍        | 18/125 [00:49<04:38,  2.60s/it]
# Velocity Estimation:  15%|█▌        | 19/125 [00:52<04:29,  2.55s/it]
# Velocity Estimation:  16%|█▌        | 20/125 [00:54<04:28,  2.56s/it]
# Velocity Estimation:  17%|█▋        | 21/125 [00:57<04:22,  2.52s/it]
# Velocity Estimation:  18%|█▊        | 22/125 [00:59<04:14,  2.47s/it]
# Velocity Estimation:  18%|█▊        | 23/125 [01:01<04:08,  2.43s/it]
# Velocity Estimation:  19%|█▉        | 24/125 [01:04<04:17,  2.55s/it]
# Velocity Estimation:  20%|██        | 25/125 [01:06<04:04,  2.45s/it]
# Velocity Estimation:  21%|██        | 26/125 [01:09<04:05,  2.48s/it]
# Velocity Estimation:  22%|██▏       | 27/125 [01:12<04:15,  2.61s/it]
# Velocity Estimation:  22%|██▏       | 28/125 [01:14<04:15,  2.64s/it]
# Velocity Estimation:  23%|██▎       | 29/125 [01:17<04:04,  2.55s/it]
# Velocity Estimation:  24%|██▍       | 30/125 [01:19<04:00,  2.54s/it]
# Velocity Estimation:  25%|██▍       | 31/125 [01:22<03:55,  2.51s/it]
# Velocity Estimation:  26%|██▌       | 32/125 [01:24<03:55,  2.53s/it]
# Velocity Estimation:  79%|███████▉  | 99/125 [04:11<01:02,  2.42s/it]
# Velocity Estimation:  80%|████████  | 100/125 [04:14<01:04,  2.56s/it]
# Velocity Estimation:  81%|████████  | 101/125 [04:16<00:58,  2.45s/it]
# Velocity Estimation:  82%|████████▏ | 102/125 [04:19<00:57,  2.52s/it]
# Velocity Estimation:  82%|████████▏ | 103/125 [04:21<00:55,  2.52s/it]
# Velocity Estimation:  83%|████████▎ | 104/125 [04:24<00:56,  2.68s/it]
# Velocity Estimation:  84%|████████▍ | 105/125 [04:26<00:50,  2.54s/it]
# Velocity Estimation:  85%|████████▍ | 106/125 [04:29<00:46,  2.47s/it]
# Velocity Estimation:  86%|████████▌ | 107/125 [04:31<00:43,  2.41s/it]
# Velocity Estimation:  86%|████████▋ | 108/125 [04:33<00:41,  2.44s/it]
# Velocity Estimation:  87%|████████▋ | 109/125 [04:36<00:38,  2.38s/it]
# Velocity Estimation:  88%|████████▊ | 110/125 [04:38<00:36,  2.44s/it]
# Velocity Estimation:  89%|████████▉ | 111/125 [04:41<00:35,  2.51s/it]
# Velocity Estimation:  90%|████████▉ | 112/125 [04:44<00:33,  2.55s/it]
# Velocity Estimation:  90%|█████████ | 113/125 [04:46<00:29,  2.49s/it]
# Velocity Estimation:  91%|█████████ | 114/125 [04:49<00:27,  2.53s/it]
# Velocity Estimation:  92%|█████████▏| 115/125 [04:51<00:25,  2.53s/it]
# Velocity Estimation:  93%|█████████▎| 116/125 [04:54<00:22,  2.52s/it]
# Velocity Estimation:  94%|█████████▎| 117/125 [04:56<00:20,  2.50s/it]
# Velocity Estimation:  94%|█████████▍| 118/125 [04:59<00:17,  2.56s/it]
# Velocity Estimation:  95%|█████████▌| 119/125 [05:01<00:15,  2.62s/it]
# Velocity Estimation:  96%|█████████▌| 120/125 [05:04<00:12,  2.55s/it]
# Velocity Estimation:  97%|█████████▋| 121/125 [05:07<00:10,  2.58s/it]
# Velocity Estimation:  98%|█████████▊| 122/125 [05:09<00:07,  2.47s/it]
# Velocity Estimation:  98%|█████████▊| 123/125 [05:11<00:05,  2.51s/it]
# Velocity Estimation:  99%|█████████▉| 124/125 [05:14<00:02,  2.46s/it]
# Velocity Estimation: 100%|██████████| 125/125 [05:16<00:00,  2.46s/it]
#                                                                                                                                                  Not predicted gene list:['Crip1', 'Acta2', 'Col1a2']. Try visualizing the unspliced and spliced columns of the gene(s) to check the quality.

# %%
cellDancer_df=cd.compute_cell_velocity(cellDancer_df=cellDancer_df, projection_neighbor_choice='gene', expression_scale='power10', projection_neighbor_size=200)

# %%
cellDancer_df.to_csv("data/celldancer_result.csv")

# %%
adata_celldancer = cdutil.to_dynamo(cellDancer_df)

# %%
adata_celldancer.write_h5ad("data/celldancer.h5ad")
