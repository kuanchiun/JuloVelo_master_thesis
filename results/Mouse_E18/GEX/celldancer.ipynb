# %%
import os
import sys
import glob
import pandas as pd
import math
import matplotlib.pyplot as plt
import celldancer as cd
import celldancer.cdplt as cdplt
from celldancer.cdplt import colormap
import scvelo as scv
import scanpy as sc
import celldancer.utilities as cdutil
import numpy as np
import seaborn as sns

# %%
adata = scv.read("../velocyto/10X_multiome_mouse_brain.loom", cache = True)

# %%
adata.obs_names = [x.split(':')[1][:-1] + '-1' for x in adata.obs_names]
adata.var_names_make_unique()

# %%
cell_annot = pd.read_csv('../cell_annotations.tsv', sep='\t', index_col=0)

# %%
adata = adata[cell_annot.index,:]
adata.obs['celltype'] = cell_annot['celltype']

# %%
adata = adata[adata.obs['celltype'].isin(['RG, Astro, OPC', 
                                                      'IPC', 
                                                      'V-SVZ', 
                                                      'Upper Layer', 
                                                      'Deeper Layer', 
                                                      'Ependymal cells', 
                                                      'Subplate'])]

# %%
adata.obs['celltype'] = cell_annot.loc[adata.obs_names, 'celltype']
adata.obs['celltype'] = adata.obs['celltype'].astype('category')

# %%
scv.pl.proportions(adata, groupby = "celltype")

# %%
scv.pp.filter_and_normalize(adata, min_shared_counts=20, n_top_genes=1000)
scv.pp.moments(adata, n_pcs=30, n_neighbors=30)
# Out:
# Filtered out 23038 genes that are detected 20 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 1000 highly variable genes.
# Logarithmized X.
# computing neighbors
#     finished (0:00:03) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)

# %%
sc.tl.leiden(adata)

# %%
scv.tl.umap(adata)
scv.pl.umap(adata, color='celltype')

# %%
cdutil.adata_to_df_with_embed(adata,
                              us_para = ['Mu','Ms'],
                              cell_type_para = 'celltype',
                              embed_para = 'X_umap',
                              save_path = 'celldancer_predata.csv')
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:07<00:00, 133.91it/s]
#         gene_name  unsplice    splice              cellID         clusters  \
# 0           Mybl1  0.027261  0.000000  AACCTTAAGTAGCGGG-1   RG, Astro, OPC
# 1           Mybl1  0.000000  0.000000  AACAGCAAGTTATCCT-1         Subplate
# 2           Mybl1  0.000000  0.000000  AACTAGCTCAATGTGC-1              IPC
# 3           Mybl1  0.000000  0.000000  AAAGGCTCACCTGGTG-1  Ependymal cells
# 4           Mybl1  0.338705  0.058017  AACTAGCTCAGCACGC-1   RG, Astro, OPC
# ...           ...       ...       ...                 ...              ...
# 3652995   Gm47283  0.122144  0.194629  TTTCTTGCAGCCTGCA-1  Ependymal cells
# 3652996   Gm47283  0.322022  0.338967  TTTGGTAAGCGATACT-1            V-SVZ
# 3652997   Gm47283  0.535050  0.396574  TTTGGTAAGTGAGCGG-1   RG, Astro, OPC
# 3652998   Gm47283  0.352806  0.298848  TTTGCGGAGGGCCATC-1      Upper Layer
# 3652999   Gm47283  0.138707  0.333264  TTTGTCCCAATTTAGC-1         Subplate
#
#          embedding1  embedding2
# 0         12.208915   10.687434
# 1          9.751957    9.393094
# 2          5.539106    8.916688
# 3          6.489529    8.962605
# 4          1.354142   10.632039
# ...             ...         ...
# 3652995    5.671690    8.905957
# 3652996    9.554563   13.046546
# 3652997    1.055119   10.634164
# 3652998   12.763318    7.944218
# 3652999   10.227189    8.226645
#
# [3653000 rows x 7 columns]

# %%
cell_type_u_s = pd.read_csv('celldancer_predata.csv')

# %%
loss_df, cellDancer_df = cd.velocity(cell_type_u_s, permutation_ratio = 0.125, n_jobs = 16)
# Out:
# Using /media/data/bmi111/KuanChiun/temp/MultiVelo/thesis/results/Mouse_E18/GEX/cellDancer_velocity_2024-05-20 23-02-05 as the output path.
# Arranging genes for parallel job.
# 1000  genes were arranged to  63  portions.
# Velocity Estimation:   0%|          | 0/63 [00:00<?, ?it/s]
# Velocity Estimation:   2%|▏         | 1/63 [00:05<06:07,  5.93s/it]
# Velocity Estimation:   3%|▎         | 2/63 [00:08<04:15,  4.18s/it]
# Velocity Estimation:   5%|▍         | 3/63 [00:11<03:25,  3.42s/it]
# Velocity Estimation:   6%|▋         | 4/63 [00:14<03:07,  3.18s/it]
# Velocity Estimation:   8%|▊         | 5/63 [00:17<02:59,  3.09s/it]
# Velocity Estimation:  10%|▉         | 6/63 [00:20<02:51,  3.01s/it]
# Velocity Estimation:  11%|█         | 7/63 [00:22<02:39,  2.85s/it]
# Velocity Estimation:  13%|█▎        | 8/63 [00:24<02:26,  2.67s/it]
# Velocity Estimation:  14%|█▍        | 9/63 [00:27<02:25,  2.70s/it]
# Velocity Estimation:  16%|█▌        | 10/63 [00:30<02:27,  2.79s/it]
# Velocity Estimation:  17%|█▋        | 11/63 [00:33<02:22,  2.73s/it]
# Velocity Estimation:  19%|█▉        | 12/63 [00:35<02:17,  2.71s/it]
# Velocity Estimation:  21%|██        | 13/63 [00:38<02:13,  2.67s/it]
# Velocity Estimation:  22%|██▏       | 14/63 [00:40<02:06,  2.59s/it]
# Velocity Estimation:  24%|██▍       | 15/63 [00:43<02:10,  2.72s/it]
# Velocity Estimation:  25%|██▌       | 16/63 [00:46<02:12,  2.83s/it]
# Velocity Estimation:  27%|██▋       | 17/63 [00:49<02:05,  2.73s/it]
# Velocity Estimation:  29%|██▊       | 18/63 [00:52<02:04,  2.77s/it]
# Velocity Estimation:  30%|███       | 19/63 [00:55<02:02,  2.79s/it]
# Velocity Estimation:  32%|███▏      | 20/63 [00:57<02:01,  2.82s/it]
# Velocity Estimation:  33%|███▎      | 21/63 [01:00<01:59,  2.84s/it]
# Velocity Estimation:  35%|███▍      | 22/63 [01:03<01:51,  2.72s/it]
# Velocity Estimation:  37%|███▋      | 23/63 [01:06<01:57,  2.94s/it]
# Velocity Estimation:  38%|███▊      | 24/63 [01:09<01:55,  2.96s/it]
# Velocity Estimation:  40%|███▉      | 25/63 [01:12<01:52,  2.96s/it]
# Velocity Estimation:  41%|████▏     | 26/63 [01:15<01:48,  2.93s/it]
# Velocity Estimation:  95%|█████████▌| 60/63 [02:45<00:08,  2.71s/it]
# Velocity Estimation:  97%|█████████▋| 61/63 [02:47<00:05,  2.65s/it]
# Velocity Estimation:  98%|█████████▊| 62/63 [02:50<00:02,  2.65s/it]
# Velocity Estimation: 100%|██████████| 63/63 [02:51<00:00,  2.24s/it]
#                                                                                                                                                                                                                  Not predicted gene list:['Rgs5', 'Ndufa4l2', 'AU021092', 'Epas1', 'Eng', 'Mecom', 'Kcnj8', 'Slc6a13', 'Apold1', 'Igf2', 'Fli1']. Try visualizing the unspliced and spliced columns of the gene(s) to check the quality.

# %%
cellDancer_df=cd.compute_cell_velocity(cellDancer_df=cellDancer_df, projection_neighbor_choice='gene', expression_scale='power10', projection_neighbor_size=200)
# Out:
# Caution! Overwriting the 'velocity' columns.

# %%
import random
# set parameters
dt = 0.05
t_total = {dt:int(10/dt)}
n_repeats = 8

# estimate pseudotime
cellDancer_df = cd.pseudo_time(cellDancer_df=cellDancer_df,
                               grid=(30,30),
                               dt=dt,
                               t_total=t_total[dt],
                               n_repeats=n_repeats,
                               speed_up=(100,100),
                               n_paths = 3,
                               plot_long_trajs=True,
                               psrng_seeds_diffusion=[i for i in range(n_repeats)],
                               n_jobs=8)
# Out:
# Pseudo random number generator seeds are set to:  [0, 1, 2, 3, 4, 5, 6, 7]
# Generating Trajectories: 100%|███████████████████████████████████████████████████████████████████████████| 12936/12936 [00:01<00:00, 9077.16it/s]
# There are 3 clusters.
# [0 1 2]
# --- 138.70519852638245 seconds ---

# %%
# plot pseudotime
fig, ax = plt.subplots(figsize=(6,6))
im=cdplt.scatter_cell(ax,cellDancer_df, colors='pseudotime', alpha=1.0, velocity=False)
ax.axis('off')
plt.show()

# %%
cellDancer_df.to_csv("data/celldancer_result.csv")

# %%
adata_celldancer = cdutil.to_dynamo(cellDancer_df)

# %%
adata_celldancer
# Out:
# AnnData object with n_obs × n_vars = 3653 × 989
#     obs: 'clusters'
#     var: 'highly_variable_genes', 'loss', 'use_for_dynamics', 'use_for_transition'
#     uns: 'dynamics'
#     obsm: 'X_cdr', 'velocity_cdr'
#     layers: 'X_spliced', 'X_unspliced', 'M_s', 'M_u', 'velocity_S', 'velocity_U', 'alpha', 'beta', 'gamma'
#     obsp: 'connectivities', 'distances'

# %%
clusters = list(cellDancer_df["cellID"][0:3653])

# %%
times = list(cellDancer_df["pseudotime"][0:3653])

# %%
match_dict = {k:v for k, v in zip(clusters, times)}

# %%
cellID = adata_celldancer.obs_names

# %%
pseudotime = [match_dict[item] for item in cellID]

# %%
adata_celldancer.obs["pseudotime"] = pseudotime

# %%
adata_celldancer.write_h5ad("data/celldancer.h5ad")
